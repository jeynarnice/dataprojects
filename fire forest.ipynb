# %%
pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.5/112.6 GB disk)

# %%
from ultralytics import YOLO
from PIL import Image
import requests

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/ml/fire smoke.v1i.yolov11'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data= "/content/drive/MyDrive/Colab Notebooks/ml/forest fire.v5i.yolov11/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # use GPU; '0' specifies the first GPU   or device=0,1,2,3 or device=cpu
    workers=2  # use multiple workers for data loading
)

# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/detect/train22/confusion_matrix_normalized.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/detect/train2/val_batch0_pred.jpg', width=600)

# %%
from ultralytics import YOLO
# Load the model
model = YOLO('/content/runs/detect/train2/weights/best.pt')

# Perform prediction
results = model.predict(source="/content/563000004326901.jpg")
results[0].show()
# Out:
# image 1/1 /content/563000004326901.jpg: 480x640 1 Heavy smoke, 1 Large fire, 1 Medium fire, 11.9ms
# Speed: 2.8ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=720x540>
